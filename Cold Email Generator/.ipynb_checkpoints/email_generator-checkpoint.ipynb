# %%
from langchain_groq import ChatGroq
import os


api_key_path = r"C:\Users\gupta\groq_api_key.txt" 


with open(api_key_path, "r") as file:
    api_key = file.read().strip() 


os.environ["GROQ_API_KEY"] = api_key


llm = ChatGroq(
    temperature = 0.2,
    groq_api_key = api_key,
    model_name = "llama3-70b-8192"
)


prompt = "Explain how LangChain works"


response = llm.invoke(prompt)


print(response.content)
# Out:
# LangChain is a fascinating AI model that combines the power of large language models with the flexibility of chain-of-thought reasoning. Here's a breakdown of how it works:
#
# **Overview**
#
# LangChain is a type of cognitive architecture that leverages the strengths of large language models (LLMs) to perform complex reasoning tasks. It's designed to mimic human-like problem-solving abilities by generating a chain of intermediate thoughts to arrive at a solution.
#
# **Key Components**
#
# 1. **Large Language Model (LLM)**: A pre-trained language model, such as BERT or RoBERTa, that serves as the foundation of LangChain. The LLM is responsible for understanding natural language inputs and generating text outputs.
# 2. **Reasoning Module**: This module is responsible for generating a chain of intermediate thoughts to solve a problem. It takes the input prompt and uses the LLM to generate a series of intermediate thoughts, each building upon the previous one.
# 3. **Control Module**: This module oversees the reasoning process, ensuring that the chain of thoughts is coherent and relevant to the original problem.
#
# **How LangChain Works**
#
# Here's a step-by-step explanation of the LangChain process:
#
# 1. **Input Prompt**: A user provides a natural language input prompt, such as a question or problem statement.
# 2. **Initial Thought Generation**: The LLM generates an initial thought in response to the input prompt. This thought is often a simple restatement of the problem or a basic observation.
# 3. **Reasoning Module**: The Reasoning Module takes the initial thought and uses the LLM to generate a subsequent thought. This process is repeated multiple times, with each thought building upon the previous one.
# 4. **Chain of Thoughts**: The sequence of thoughts generated by the Reasoning Module forms a chain of intermediate thoughts, each linked to the previous one through logical connections.
# 5. **Control Module**: The Control Module monitors the chain of thoughts, ensuring that they remain relevant to the original problem and coherent with each other.
# 6. **Final Answer Generation**: Once the chain of thoughts reaches a satisfactory conclusion, the LLM generates a final answer or solution based on the intermediate thoughts.
# 7. **Output**: The final answer is presented to the user as the output of the LangChain process.
#
# **Example**
#
# Suppose we ask LangChain to solve the following problem:
#
# "What is the capital of France?"
#
# Here's a possible chain of thoughts generated by LangChain:
#
# 1. Initial Thought: "France is a country in Europe."
# 2. Intermediate Thought 1: "The capital of a country is usually a major city."
# 3. Intermediate Thought 2: "Paris is a major city in France."
# 4. Intermediate Thought 3: "Paris is often associated with France."
# 5. Final Answer: "The capital of France is Paris."
#
# In this example, LangChain generates a chain of intermediate thoughts that lead to the final answer. Each thought builds upon the previous one, demonstrating a logical and coherent reasoning process.
#
# **Advantages**
#
# LangChain offers several advantages over traditional AI models, including:
#
# * **Improved reasoning abilities**: LangChain can tackle complex problems by breaking them down into a series of intermediate thoughts.
# * **Increased transparency**: The chain of thoughts provides a clear explanation of the reasoning process, making it easier to understand how the model arrived at a particular answer.
# * **Flexibility**: LangChain can be applied to a wide range of tasks, from question answering to text generation and beyond.
#
# Overall, LangChain represents a significant advancement in AI research, enabling machines to reason and solve problems in a more human-like fashion.

# %% [markdown]
# ## Web Scraping

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://careers.nike.com/senior-software-engineer-manufacturing-applications-global-converse-itc/job/R-54740")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Senior Software Engineer, Manufacturing Applications, Global Converse, ITC
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
#
#
#
#
#
#
# Menu
#
#
#
# Return to Previous Menu
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 Back to Search
#
#
#
# Senior Software Engineer, Manufacturing Applications, Global Converse, ITC
#
#
# Categories ID
#
#
#
# Categories URL
#
#
#
# Position Type
# Full Time
#
#
# Date Posted
#
#
#
# Primary Quest ID
#
#
#
# Second Quest ID
#
#
#
# Job Classification
#
#
#
#
# Career area
# Technology
#
#
# Location
# 4/F, WeWork, Embassy GolfLinks, Karnataka, Karnataka 560093, India
#
#
#
# Job ID
# R-54740
#
#
#
#
#
#                                     Apply Now
#
#
#
#
#
#
#
# Share Job
#
#
#
#
# Share Job Posting
#
#
#
#
#
#
# Facebook
# Opens In A New Tab
#
#
#
#
#
#
#
# LinkedIn
# Link Opens In New Window
#
#
#
#
#
#
#
#
# Email
#
#
#
#
#
#
# Close-Medium (Default Size)-icon
#
# Close Menu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Become part of the Converse Team
# Converse is a place to explore potential, break barriers and push out the edges of what can be. The company looks for
#                             people who can grow, think, dream and create. Its culture thrives by embracing diversity and rewarding imagination.
#                             The brand seeks achievers, leaders and visionaries. At Converse, it’s about each person bringing skills and passion
#                             to a challenging and constantly evolving world to make things better as a team.
#
# WHO YOU’LL WORK WITHAs a Senior Software engineer on our Factory Floor Systems team, you will be collaborating closely with other engineer FTEs on the team, as well as contractors who assist with supporting the product. You will be working in a hierarchically structured environment and communicating up to several levels of leadership. You will also work across teams with other functional development groups, architects, as well as both directly with internal and external users and key stakeholders. WHO WE ARE LOOKING FORWe are seeking an experienced Senior Software Engineer to join our Factory Floor Application (FSx) team. As a key member of our FSx team, you will provide technical support for the Converse Factory Floor System. You will be responsible for Onboarding new factory partners and code/configure, test and troubleshooting system and integration issues along with additional IT duties.• A bachelor’s degree and a minimum of 6 years of directly relevant work experience are required; alternatively, an additional 2 years of relevant experience may be considered in lieu of a degree.• 6+ years of experience developing Windows software using C#, VB.NET, ASP.NET, and Crystal Reports.• 6+ years of experience with database stored procedures, including at least 3 years using SQL Server and T-SQL.• 3+ years of experience with Azure (or similar cloud platform), GitHub & Devops (CI/CD)• 3+ years’ experience with Serverless technologies and architecture• Certification in Microsoft Azure administration a plus• Expertise in application disaster recovery solution implementations a plus• Prior experience with MRP or manufacturing floor systems (Like Andromeda, Logility Vendor management), sensors or robotics software preferred• Ability to relate or explain technical information to business stakeholders• Experience with Agile development methodologies for planning and managing work in bi-weekly sprints• Excellent Communication and Collaboration skills• Experience working with cross-functional teams across different time zonesWHAT YOU’LL WORK ON• Collaborate with internal teams, business stakeholders and Factory vendors to establish, maintain, and troubleshoot system connections, ensuring data integrity and compliance with Converse Security requirements.• Collaborate with Application vendor in prioritizing open issues and getting them resolved in a timely manner• Operate with a team that has an on-shore/ off-shore component• Manage JIRA boards for defined bodies of work• Be aware of production issues whether that is impacting one factory or all and provide immediate assistance.• Confirm all code has been thoroughly reviewed, tested, and implemented successfully.• Report on and escalate as required to leadership on project/program deliverables and timelines.• Collaborate with the Converse Security team in performing Pentest, and security controls audits.• Participate in large cross-technology project meetings to identify the impact on the team and understand the complete business requirements.• Stay up to date with product releases, updates, and industry trends.• Give feedback to the Product Manager on improving service, processes, and efficiency.
#
# Converse is more than a company; it’s a worldwide advocate for self-expression. This belief motivates our employees,
#                             permeates our working environment and inspires our products. No two of us look or think exactly alike. We are each
#                             one-of-a-kind. Individually and as a culture, we have the freedom to create and grow professionally. Generous
#                             benefits packages only sweeten the experience. From Boston to Shanghai, from Brand Design to Finance, Converse is a
#                             brand that celebrates the unique and creative people of the world. Together, we’re different.
#
#
#
#
#                                 Apply Now
#
#
#
#
#
#
#
# Share Job
#
#
#
#
# Share Job Posting
#
#
#
#
#
#
# Faceboox
# Opens In A New Tab
#
#
#
#
#
#
#
# LinkedIn
# Link Opens In New Window
#
#
#
#
#
#
#
#
# Email
#
#
#
#
#
#
# Close-Medium (Default Size)-icon
#
# Close Menu
#
#
#
#
#
#
#
#
#
#
#
# What You Can Expect
# OUR HIRING GAME PLAN
#
#
# 01 Apply
# Our teams are made up of diverse skillsets, knowledge bases, inputs, ideas and backgrounds.
#                             We want you to find your fit – review job descriptions, departments and teams to discover
#                             the role for you.
#
#
# 02 Meet a Recruiter or Take an Assessment
# If selected for a corporate role, a recruiter will reach out to start your interview process
#                             and be your main contact
#                             throughout the process. For retail roles, you’ll complete an interactive assessment that
#                             includes a chat and quizzes and
#                             takes about 10-20 minutes to complete.  No matter the role, we want to learn about you – the
#                             whole you – so don’t shy
#                             away from how you approach world-class service and what makes you unique.
#
#
# 03 Interview
# Go into this stage confident by doing your research, understanding what we are looking for
#                             and being prepared for
#                             questions that are set up to learn more about you, and your background.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# About Us
#
#
# Contact
#
#
# Talent Community
#
#
# Terms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Nike Applicant Privacy Policy
#
#
#
#
#
#
# We offer a number of accommodations to complete our interview process including screen readers, sign language interpreters,
#                 accessible and single location for in-person interviews, closed captioning, and other reasonable modifications as
#                 needed.
#
#
# If you discover, as you navigate our application process, that you need assistance or an accommodation due to a
#                 disability, please contact us at +1 503-671-4156 and include your full name, best way to reach you, and the
#                 accommodation you request to assist with the application process.
# For more information, please refer to Equal Employment
#                         Opportunity is The Law.
#
#
#
# ©  Nike, Inc. All Rights Reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
# Chat
# Chat with our AI Assistant

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Senior Software Engineer, Manufacturing Applications, Global Converse, ITC',
#   'experience': '6+ years',
#   'skills': ['C#',
#    'VB.NET',
#    'ASP.NET',
#    'Crystal Reports',
#    'SQL Server',
#    'T-SQL',
#    'Azure',
#    'GitHub',
#    'Devops (CI/CD)',
#    'Serverless technologies',
#    'Microsoft Azure administration',
#    'MRP or manufacturing floor systems',
#    'Agile development methodologies'],
#   'description': 'Collaborate with internal teams, business stakeholders and Factory vendors to establish, maintain, and troubleshoot system connections, ensuring data integrity and compliance with Converse Security requirements.'}]

# %%
type(json_res)
# Out:
# list

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
links = collection.query(query_texts=json_res[0]['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/angular-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/angular-portfolio'},
#   {'links': 'https://example.com/ml-python-portfolio'}],
#  [{'links': 'https://example.com/angular-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/python-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/angular-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/angular-portfolio'}],
#  [{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/angular-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/devops-portfolio'},
#   {'links': 'https://example.com/ios-ar-portfolio'}],
#  [{'links': 'https://example.com/angular-portfolio'},
#   {'links': 'https://example.com/full-stack-js-portfolio'}],
#  [{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/angular-portfolio'}],
#  [{'links': 'https://example.com/android-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/ios-ar-portfolio'},
#   {'links': 'https://example.com/kotlin-backend-portfolio'}]]

# %%
json_res[0]['skills']
# Out:
# ['C#',
#  'VB.NET',
#  'ASP.NET',
#  'Crystal Reports',
#  'SQL Server',
#  'T-SQL',
#  'Azure',
#  'GitHub',
#  'Devops (CI/CD)',
#  'Serverless technologies',
#  'Microsoft Azure administration',
#  'MRP or manufacturing floor systems',
#  'Agile development methodologies']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(json_res), "link_list": links})
print(res.content)
# Out:
# Subject: Expertise in Manufacturing Applications and Azure Development for Converse, ITC
#
# Dear Hiring Manager,
#
# I came across the job description for a Senior Software Engineer, Manufacturing Applications, Global Converse, ITC, and was impressed by the scope of the project. As a business development executive at AtliQ, I believe our team can provide the necessary expertise to fulfill your requirements.
#
# AtliQ has extensive experience in developing and integrating manufacturing applications, leveraging technologies such as C#, ASP.NET, and SQL Server. Our team is well-versed in Azure development, including serverless technologies, and has a strong understanding of DevOps practices (CI/CD) and Microsoft Azure administration.
#
# Our portfolio showcases our capabilities in developing scalable and efficient solutions for various industries. Some relevant examples include our work on [https://example.com/angular-portfolio] and [https://example.com/devops-portfolio], which demonstrate our expertise in Azure development and DevOps practices.
#
# We understand the importance of data integrity and compliance with security requirements. Our team is committed to ensuring the highest level of security and compliance in all our projects.
#
# I would be delighted to discuss how AtliQ can support Converse, ITC, in achieving its goals. Please let me know if you would like to schedule a call to explore further.
#
# Best regards,
#
# Mohan
# Business Development Executive
# AtliQ
